# %%
fistString <- "Hello Word!"
print(fistString)
# Out:
# [1] "Hello Word!"

# %%
y1<-rnorm(100);y2<-rexp(100,2)
par(mfrow = c(3,3))
hist(y1,xlim=c(-5,5))
hist(y2)
# Out:
# Plot with title "Histogram of y2"
